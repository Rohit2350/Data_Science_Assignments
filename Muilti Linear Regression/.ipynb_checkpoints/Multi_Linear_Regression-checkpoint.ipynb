# %% [markdown]
# # Multi Linear Regression

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
from sklearn.linear_model import Ridge, RidgeCV, Lasso

# %% [markdown]
# ***

# %% [markdown]
# ## Q1

# %%
df1=pd.read_csv("50_Startups.csv")
df1.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %%
df1.shape
# Out:
# (50, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data1=df1.rename({"R&D Spend":"RD","Administration":"ADM","Marketing Spend":"MS"},axis=1)
data1.head(5)
# Out:
#           RD        ADM         MS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
data1.describe()
# Out:
#                   RD            ADM             MS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %%
data1[data1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [RD, ADM, MS, State, Profit]
# Index: []

# %%
data1.corr()
# Out:
# C:\Users\ROHIT\AppData\Local\Temp\ipykernel_14260\3734675979.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data1.corr()
#               RD       ADM        MS    Profit
# RD      1.000000  0.241955  0.724248  0.972900
# ADM     0.241955  1.000000 -0.032154  0.200717
# MS      0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data1)

# %%
model1=smf.ols("Profit~RD+ADM+MS",data=data1).fit()
model1

# %%
model1.params
# Out:
# Intercept    50122.192990
# RD               0.805715
# ADM             -0.026816
# MS               0.027228
# dtype: float64

# %%
model1.tvalues, np.round(model1.pvalues,3)
# Out:
# (Intercept     7.626218
#  RD           17.846374
#  ADM          -0.525507
#  MS            1.655077
#  dtype: float64,
#  Intercept    0.000
#  RD           0.000
#  ADM          0.602
#  MS           0.105
#  dtype: float64)

# %%
model1.rsquared, model1.rsquared_adj
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %%
A1=smf.ols('Profit~ADM',data=data1).fit()
A1.tvalues , A1.pvalues
# Out:
# (Intercept    3.040044
#  ADM          1.419493
#  dtype: float64,
#  Intercept    0.003824
#  ADM          0.162217
#  dtype: float64)

# %%
B1=smf.ols('Profit~MS',data=data1).fit()
B1.tvalues , B1.pvalues
# Out:
# (Intercept    7.808356
#  MS           7.802657
#  dtype: float64,
#  Intercept    4.294735e-10
#  MS           4.381073e-10
#  dtype: float64)

# %%
C1=smf.ols('Profit~MS+ADM',data=data1).fit()
C1.tvalues , C1.pvalues
# Out:
# (Intercept    1.142741
#  MS           8.281039
#  ADM          2.467779
#  dtype: float64,
#  Intercept    2.589341e-01
#  MS           9.727245e-11
#  ADM          1.729198e-02
#  dtype: float64)

# %%
rqs = smf.ols("RD~ADM+MS",data=data1).fit().rsquared
vif = 1/(1-rqs)

rqs1 = smf.ols("ADM~RD+MS",data=data1).fit().rsquared
vif1 = 1/(1-rqs1)

rqs2 = smf.ols("MS~RD+ADM",data=data1).fit().rsquared
vif2 = 1/(1-rqs2)

# %%
DATA1={'Variables':['RDS','ADMS','MS'],'Vif':[vif,vif1,vif2]}
Vif_df=pd.DataFrame(DATA1)
Vif_df
# Out:
#   Variables       Vif
# 0       RDS  2.468903
# 1      ADMS  1.175091
# 2        MS  2.326773

# %%
import statsmodels.api as sm
sm.qqplot(model1.resid, line='q')
plt.title('q-q plot')
# Out:
# Text(0.5, 1.0, 'q-q plot')

# %%
def standard_values(vals) : return (vals-vals.mean())/vals.std()

# %%
plt.scatter(standard_values(model1.fittedvalues),standard_values(model1.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model1,'RD',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model1,'ADM',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model1,'MS',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
(c,_)=model1.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data1)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
np.argmax(c) , np.max(c)
# Out:
# (49, 0.2880822927543264)

# %%
influence_plot(model1)
plt.show()

# %%
k=data1.shape[1]
n=data1.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
data1[data1.index.isin([49])]
# Out:
#      RD       ADM        MS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %%
DATA1=data1.drop(data1.index[[49]],axis=0).reset_index(drop=True)
DATA1
# Out:
#            RD        ADM         MS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
while np.max(c)>0.5 :
    model=smf.ols("Profit~RD+ADM+MS",data=DATA1).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data2=data2.drop(DATA1.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data2
else:
    final_model=smf.ols("Profit~RD+ADM+MS",data=DATA1).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9613162435129847

# %%
newd=pd.DataFrame({'RD':70000,"ADM":90000,"MS":140000},index=[0])
newd
# Out:
#       RD    ADM      MS
# 0  70000  90000  140000

# %%
final_model.predict(newd)
# Out:
# 0    108727.154753
# dtype: float64

# %%
pred_y=final_model.predict(DATA1)
pred_y
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...

# %%
d2={'Prep_Models':['Model','Final_Model'],'Rsquared':[model1.rsquared,final_model.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  0.961316
